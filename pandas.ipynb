# %% [markdown]
# ### Pandas

# %%
import pandas as pd 
import numpy as np
from io import StringIO

# %%
### serious 1 d array 

data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
print(type(series)) #### the 0 1 2 3 4 are indexes
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
### create a serious from dictionary
data={'a':1,'b':2,'c':3}
serious=pd.Series(data)
serious
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
### DataFrame
## create a datafram  from a dictionary
data={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Texes']
}

df=pd.DataFrame(data)
df
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45      Texes

# %%
np.array(df)
# Out:
# array([['Krish', 25, 'Bangalore'],
#        ['John', 30, 'New York'],
#        ['Jack', 45, 'Texes']], dtype=object)

# %%
### Create a Data frame From a List of Dictionaries
data=[
    {'Name':'Mohammad','Age':32,'City':'Bangalore'},
     {'Name':'Jack','Age':32,'City':'Bangalore'},
      {'Name':'Jhon','Age':32,'City':'Bangalore'},
       {'Name':'Mohammad','Age':32,'City':'Bangalore'}
]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#        Name  Age       City
# 0  Mohammad   32  Bangalore
# 1      Jack   32  Bangalore
# 2      Jhon   32  Bangalore
# 3  Mohammad   32  Bangalore
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
### Accessing data from DataFrame
type(df['Value'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0]
# Out:
# Date        2023-01-01
# Category             A
# Value             28.0
# Product       Product1
# Sales            754.0
# Region            East
# Name: 0, dtype: object

# %%
df.iloc[0][1]
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_36716\2309508539.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][1]
# 'A'

# %%
#### Accissing specified element 
df['Category'].head()
# Out:
# 0    A
# 1    B
# 2    C
# 3    B
# 4    B
# Name: Category, dtype: object

# %%
data={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Texes']
}

df=pd.DataFrame(data)
df
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45      Texes

# %%
df.at[2,"Age"]
# Out:
# 45

# %%
df.at[2,'Name']
# Out:
# 'Jack'

# %%
###Accessing A specified element using iat
df.iat[2,2]### Index and Columns
# Out:
# 'Texes'

# %%
### Data Manipulation 
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45      Texes

# %%
### Adding a Column
df['Salary']=[50000,600000,70000]
df
# Out:
#     Name  Age       City  Salary
# 0  Krish   25  Bangalore   50000
# 1   John   30   New York  600000
# 2   Jack   45      Texes   70000

# %%
### Remove a column 
### 0 means that we are selecting rows, 1 means that we are selecting columns
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45      Texes

# %%
### Add age to the column
df['Age']=df['Age']+1
df
# Out:
#     Name  Age       City
# 0  Krish   26  Bangalore
# 1   John   31   New York
# 2   Jack   46      Texes

# %%
df.drop(0)### Drop Row
# Out:
#    Name  Age      City
# 1  John   31  New York
# 2  Jack   46     Texes

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
### Display the data types of each column 
print("Data types:\n",df.dtypes)
# Out:
# Data types:
#  Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
### Describe the Dataframe 
print("Statistical Summary:\n",df.describe())
# Out:
# Statistical Summary:
#             Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
# Group by column and perform an aggregation 
grouped=df.groupby('Category')['Value'].mean()
print("Mean Value by Category:\n",grouped)
# Out:
# Mean Value by Category:
#  Category
# A    48.357143
# B    44.142857
# C    59.842105
# Name: Value, dtype: float64

# %% [markdown]
# ### Data Manipulation And Analysis with Pandas

# %%
df=pd.read_csv('data.csv')
### Fetch the first 5 Rows
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail()
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
#### Handling Missing Values 
df.isnull().any()
# Out:
# Date        False
# Category    False
# Value        True
# Product     False
# Sales        True
# Region      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
### Filling missing Values with the mean of the column
df['Sales_fillNA']=df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product  Sales Region  Sales_fillNA
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
df.dtypes
# Out:
# Date             object
# Category         object
# Value           float64
# Product          object
# Sales           float64
# Region           object
# Sales_fillNA    float64
# dtype: object

# %%
### Renaming Columns 
df=df.rename(columns={'Date':'Sale_Date'})
df.head()
# Out:
#     Sale_Date Category  Value   Product  Sales Region  Sales_fillNA
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
## Cahnge The Datatype 
df['Value_New']=df['Value'].fillna(df['Value'].mean()).astype(int)
df.head()
# Out:
#     Sale_Date Category  Value   Product  Sales Region  Sales_fillNA  Value_New
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0          8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         26

# %%
df['New Value']=df['Value'].apply(lambda x:x*2)
df.head()
# Out:
#     Sale_Date Category  Value   Product  Sales Region  Sales_fillNA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
#
#    Value_New  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0

# %%
### Data Aggregating And Grouping 
df.head()
# Out:
#     Sale_Date Category  Value   Product  Sales Region  Sales_fillNA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
#
#    Value_New  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0

# %%
grouped_mean=df.groupby('Product')['Value'].mean()
grouped_mean
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouped_sum=df.groupby(['Product','Region'])['Value'].sum()
grouped_sum
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
### aggregate multiple Functions 
grouped_Agg=df.groupby('Region')['Value'].agg(['mean','sum','count'])
grouped_Agg
# Out:
#              mean     sum  count
# Region
# East    42.307692   550.0     13
# North   37.666667   339.0      9
# South   62.000000   496.0      8
# West    61.588235  1047.0     17

# %%
### Mergin and joining Dataframe 
df1=pd.DataFrame({'Key':['A','B','C'],'Value1':[1,2,3]})
df2=pd.DataFrame({'Key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
### Merge DataFrame on the "Key Columns"
pd.merge(df1,df2,on='Key',how='inner')
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on='Key',how='outer')
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on='Key',how='left')
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on='Key',how='right')
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6

# %% [markdown]
# #### Reading Data From Various Data Source Using Pandas

# %%
json_string = '''
[
    {"id": 1, "name": "John Doe", "position": "Software Engineer", "salary": 70000},
    {"id": 2, "name": "Jane Smith", "position": "Data Scientist", "salary": 85000},
    {"id": 3, "name": "Emily Davis", "position": "Product Manager", "salary": 95000}
]
'''
Data=pd.read_json(StringIO(json_string))

# %%
Data
# Out:
#    id         name           position  salary
# 0   1     John Doe  Software Engineer   70000
# 1   2   Jane Smith     Data Scientist   85000
# 2   3  Emily Davis    Product Manager   95000

# %%
### Convert Back To Jeson 
Data.to_json()
# Out:
# '{"id":{"0":1,"1":2,"2":3},"name":{"0":"John Doe","1":"Jane Smith","2":"Emily Davis"},"position":{"0":"Software Engineer","1":"Data Scientist","2":"Product Manager"},"salary":{"0":70000,"1":85000,"2":95000}}'

# %%
Data.to_json(orient="index")### Defult
# Out:
# '{"0":{"id":1,"name":"John Doe","position":"Software Engineer","salary":70000},"1":{"id":2,"name":"Jane Smith","position":"Data Scientist","salary":85000},"2":{"id":3,"name":"Emily Davis","position":"Product Manager","salary":95000}}'

# %%
Data.to_json(orient="records")
# Out:
# '[{"id":1,"name":"John Doe","position":"Software Engineer","salary":70000},{"id":2,"name":"Jane Smith","position":"Data Scientist","salary":85000},{"id":3,"name":"Emily Davis","position":"Product Manager","salary":95000}]'

# %%
df=pd.read_csv("https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv",header=None)

# %%
df.head()
# Out:
#        0                 1                  2
# 0  Index   Height(Inches)"   "Weight(Pounds)"
# 1      1             65.78             112.99
# 2      2             71.52             136.49
# 3      3             69.40             153.03
# 4      4             68.22             142.34

# %%
df.to_csv("height_and_weight.csv")

# %%
### Read From Html
### pip install lxml
### pip install html5lib
### pip install beautifulsoup4
url="https://www.fdic.gov/bank-failures/failed-bank-list"
df=pd.read_html(url)

# %%
df[0]
# Out:
#                                Bank Name               City          State  \
# 0     The First National Bank of Lindsay            Lindsay       Oklahoma
# 1  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 2                          Citizens Bank           Sac City           Iowa
# 3               Heartland Tri-State Bank            Elkhart         Kansas
# 4                    First Republic Bank      San Francisco     California
# 5                         Signature Bank           New York       New York
# 6                    Silicon Valley Bank        Santa Clara     California
# 7                      Almena State Bank             Almena         Kansas
# 8             First City Bank of Florida  Fort Walton Beach        Florida
# 9                   The First State Bank      Barboursville  West Virginia
#
#     Cert                 Aquiring Institution      Closing Date  \
# 0   4134   First Bank & Trust Co., Duncan, OK  October 18, 2024
# ...

# %%
url="https://en.wikipedia.org/wiki/Mobile_country_code"
pd.read_html(url,match="Country",header=0)[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
### Excel Data 
### pip install openpyxl
df_excel=pd.read_excel("sample_data.xlsx")

# %%
### convert to pickl 
df_excel.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#        Name  Age
# 0  Mohammad   24
# 1      Hala   28
# 2     Cilin   26
# 3    Shadid   45
